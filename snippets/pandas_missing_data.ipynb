# %% [markdown]
# ### Missing data (Sentinel Values)
# - nan, np.nan, None as called sentinel values

# %%
import pandas as pd
from numpy import nan

weekdays = pd.Series(['sunday', nan, 'monday', 'tuesday', None, nan, 'friday', 'saturday'])
weekdays.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# dtype: bool

# %% [markdown]
# ### Series: Remove Missing Data

# %%
### drop na values
display(weekdays.dropna())

### it can be done like
display(weekdays[weekdays.notnull()])
# Out:
# 0      sunday
# 2      monday
# 3     tuesday
# 6      friday
# 7    saturday
# dtype: object
# 0      sunday
# 2      monday
# 3     tuesday
# 6      friday
# 7    saturday
# dtype: object

# %% [markdown]
# ### Series: Fill Missing Data

# %%
### forward fill
display(weekdays.fillna(method='ffill'))
### backward fill
display(weekdays.fillna(method='bfill') )
# Out:
# 0      sunday
# 1      sunday
# 2      monday
# 3     tuesday
# 4     tuesday
# 5     tuesday
# 6      friday
# 7    saturday
# dtype: object
# 0      sunday
# 1      monday
# 2      monday
# 3     tuesday
# 4      friday
# 5      friday
# 6      friday
# 7    saturday
# dtype: object

# %% [markdown]
# ### DataFrame: Remove Rows Missing Data

# %%
import numpy as np
arr = np.random.rand(10,5)

arr[arr<0.3] = nan
arr[2:4] = nan
df = pd.DataFrame(arr)
display(df)

display("Remove all rows with missing data", df.dropna())
display("Remove rows with all values missing", df.dropna(how='all'))
display("Remove rows which has less than 3 values", df.dropna(thresh=3))
# Out:
#           0         1         2         3         4
# 0  0.646477  0.455008       NaN       NaN  0.464423
# 1       NaN  0.531666       NaN       NaN  0.644894
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4  0.957424  0.854721  0.863963       NaN  0.440233
# 5  0.934556  0.373860  0.366724  0.810804  0.853117
# 6       NaN  0.654670       NaN  0.311088       NaN
# 7  0.508919  0.479805  0.359499  0.825992  0.454949
# 8       NaN  0.561319  0.684116  0.782834  0.943531
# 9  0.634897  0.579550       NaN  0.607956       NaN
# 'Remove all rows with missing data'
#           0         1         2         3         4
# 5  0.934556  0.373860  0.366724  0.810804  0.853117
# 7  0.508919  0.479805  0.359499  0.825992  0.454949
# 'Remove rows with all values missing'
#           0         1         2         3         4
# 0  0.646477  0.455008       NaN       NaN  0.464423
# 1       NaN  0.531666       NaN       NaN  0.644894
# 4  0.957424  0.854721  0.863963       NaN  0.440233
# 5  0.934556  0.373860  0.366724  0.810804  0.853117
# 6       NaN  0.654670       NaN  0.311088       NaN
# 7  0.508919  0.479805  0.359499  0.825992  0.454949
# 8       NaN  0.561319  0.684116  0.782834  0.943531
# 9  0.634897  0.579550       NaN  0.607956       NaN
# 'Remove rows which has less than 3 values'
#           0         1         2         3         4
# 0  0.646477  0.455008       NaN       NaN  0.464423
# 4  0.957424  0.854721  0.863963       NaN  0.440233
# 5  0.934556  0.373860  0.366724  0.810804  0.853117
# 7  0.508919  0.479805  0.359499  0.825992  0.454949
# 8       NaN  0.561319  0.684116  0.782834  0.943531
# 9  0.634897  0.579550       NaN  0.607956       NaN

# %% [markdown]
# ### DataFrame: Remove Columns With Missing Data

# %%
### dropna will return new dataframe. To change in place user inplace=True
df_copy = df.copy()
df_copy.dropna(axis=1, thresh=5, inplace=True)
df_copy
# Out:
#           0         1         3         4
# 0  0.646477  0.455008       NaN  0.464423
# 1       NaN  0.531666       NaN  0.644894
# 2       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN
# 4  0.957424  0.854721       NaN  0.440233
# 5  0.934556  0.373860  0.810804  0.853117
# 6       NaN  0.654670  0.311088       NaN
# 7  0.508919  0.479805  0.825992  0.454949
# 8       NaN  0.561319  0.782834  0.943531
# 9  0.634897  0.579550  0.607956       NaN

# %% [markdown]
# ### DataFrame: Fill Missing Data

# %%
df.fillna(0)
# Out:
#           0         1         3         4
# 0  0.646477  0.455008  0.000000  0.464423
# 1  0.000000  0.531666  0.000000  0.644894
# 2  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000
# 4  0.957424  0.854721  0.000000  0.440233
# 5  0.934556  0.373860  0.810804  0.853117
# 6  0.000000  0.654670  0.311088  0.000000
# 7  0.508919  0.479805  0.825992  0.454949
# 8  0.000000  0.561319  0.782834  0.943531
# 9  0.634897  0.579550  0.607956  0.000000

# %% [markdown]
# #### Fill different values for each columns

# %%
df.fillna({0:0, 1:-1})
# Out:
#           0         1         3         4
# 0  0.646477  0.455008       NaN  0.464423
# 1  0.000000  0.531666       NaN  0.644894
# 2  0.000000 -1.000000       NaN       NaN
# 3  0.000000 -1.000000       NaN       NaN
# 4  0.957424  0.854721       NaN  0.440233
# 5  0.934556  0.373860  0.810804  0.853117
# 6  0.000000  0.654670  0.311088       NaN
# 7  0.508919  0.479805  0.825992  0.454949
# 8  0.000000  0.561319  0.782834  0.943531
# 9  0.634897  0.579550  0.607956       NaN

# %% [markdown]
# #### Forward Fill

# %%
df.fillna(method='ffill', limit=2) ## limit = number of consecutive steps to fill
# Out:
#           0         1         3         4
# 0  0.646477  0.455008       NaN  0.464423
# 1  0.646477  0.531666       NaN  0.644894
# 2  0.646477  0.531666       NaN  0.644894
# 3       NaN  0.531666       NaN  0.644894
# 4  0.957424  0.854721       NaN  0.440233
# 5  0.934556  0.373860  0.810804  0.853117
# 6  0.934556  0.654670  0.311088  0.853117
# 7  0.508919  0.479805  0.825992  0.454949
# 8  0.508919  0.561319  0.782834  0.943531
# 9  0.634897  0.579550  0.607956  0.943531

# %% [markdown]
# #### Backward Fill

# %%
df.fillna(method='bfill', limit=2)
# Out:
#           0         1         3         4
# 0  0.646477  0.455008       NaN  0.464423
# 1       NaN  0.531666       NaN  0.644894
# 2  0.957424  0.854721       NaN  0.440233
# 3  0.957424  0.854721  0.810804  0.440233
# 4  0.957424  0.854721  0.810804  0.440233
# 5  0.934556  0.373860  0.810804  0.853117
# 6  0.508919  0.654670  0.311088  0.454949
# 7  0.508919  0.479805  0.825992  0.454949
# 8  0.634897  0.561319  0.782834  0.943531
# 9  0.634897  0.579550  0.607956       NaN

# %% [markdown]
# #### Fill with Mean or Median

# %%
display(df.fillna(df.mean()))
display(df.mean())
# Out:
#           0         1         3         4
# 0  0.646477  0.455008  0.667735  0.464423
# 1  0.736455  0.531666  0.667735  0.644894
# 2  0.736455  0.561325  0.667735  0.633524
# 3  0.736455  0.561325  0.667735  0.633524
# 4  0.957424  0.854721  0.667735  0.440233
# 5  0.934556  0.373860  0.810804  0.853117
# 6  0.736455  0.654670  0.311088  0.633524
# 7  0.508919  0.479805  0.825992  0.454949
# 8  0.736455  0.561319  0.782834  0.943531
# 9  0.634897  0.579550  0.607956  0.633524
# 0    0.736455
# 1    0.561325
# 3    0.667735
# 4    0.633524
# dtype: float64

# %% [markdown]
# ### Duplicate Data

# %%
arr1 = np.random.choice(range(10), (7, 5))
arr2 = np.random.choice (range(5), (7,1))

arr = np.concatenate((arr1, arr2), axis=1)

dup_df = pd.DataFrame(arr, columns = list('_abcde'))

display(dup_df.duplicated(['_']))

display(dup_df.drop_duplicates(['_'], keep='last'))
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# dtype: bool
#    _  a  b  c  d  e
# 0  2  7  3  5  6  2
# 3  5  0  8  0  0  0
# 4  3  3  6  6  7  2
# 5  6  5  7  8  5  3
# 6  1  8  7  6  5  1
