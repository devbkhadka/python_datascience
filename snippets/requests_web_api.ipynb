# %%
import requests
import json
resp = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
issues = resp.json()
issues[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/25402',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/25402/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/25402/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/25402/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/25402',
#  'id': 412995004,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0MjU1MDc5NTUz',
#  'number': 25402,
#  'title': 'CI: Set pytest minversion to 4.0.2',
#  'user': {'login': 'simonjayhawkins',
#   'id': 13159005,
#   'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/simonjayhawkins',
#   'html_url': 'https://github.com/simonjayhawkins',
# ...

# %%
import pandas as pd
df_issues = pd.DataFrame(issues, columns=['number', 'title', 'updated_at'])
df_issues
# Out:
#     number                                              title  \
# 0    25402                 CI: Set pytest minversion to 4.0.2
# 1    25400         Mark test_pct_max_many_rows as high memory
# 2    25399  Inconsistent handling of duplicate axes + mixe...
# 3    25398   Please add more ways to remove header formatting
# 4    25397  DataFrame groupby.first() is much slower than ...
# 5    25396                pd.Interval default closed='right'?
# 6    25395  pd.Series.isin has different behaviour based o...
# 7    25394  BUG: pd.Series.interpolate non-numeric index c...
# 8    25393  ImportError: sys.meta_path is None, Python is ...
# 9    25384  test_pct_max_many_rows fails on intel 32bit wi...
# 10   25383       Setting with enlargement on categorical data
# 11   25379  Reading/writing of W3C-style embeded metadata ...
# 12   25378  BUG: SparseDataFrame indexing sometimes loses ...
# 13   25377  CI: Add 'conda list' for azure/posix after act...
# ...
