# %%
import pandas as pd
pd.read_html("http://nmbbanknepal.com/forex")[0]
# Out:
#              Currency  Unit  Buying (Notes of Deno 50 and above)  \
# 0        Indian Rupee     1                                 1.60
# 1           US Dollar     1                               113.65
# 2                Euro     1                               128.23
# 3      Pound Sterling     1                               146.44
# 4         Swiss Franc     1                               112.92
# 5   Australian Dollar     1                                81.31
# 6     Canadian Dollar     1                                85.72
# 7    Singapore Dollar     1                                83.63
# 8        Japanese Yen    10                                10.26
# 9      Swedish Kroner     1                                12.19
# 10      Danish Kroner     1                                17.15
# 11    Hongkong Dollar     1                                14.41
# 12          Thai Baht     1                                 3.61
# ...

# %%
pd.read_html?
