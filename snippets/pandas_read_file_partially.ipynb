# %% [markdown]
# ### Read Top N Rows

# %%
import pandas as pd
pd.options.display.max_rows = 10
## read only top 5 rows
pd.read_csv('data/real-estate-transactions.csv', nrows=5)
# Out:
#              street        city    zip state     ...                         sale_date  price   latitude   longitude
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     ...      Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     ...      Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     ...      Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     ...      Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     ...      Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Read File in Chunks

# %%
chunker=pd.read_csv('data/real-estate-transactions.csv', chunksize=20)

for i, chunk in zip(range(3), chunker):
    display(chunk)

chunker.get_chunk(size=5)
# Out:
#                      street            city    zip     ...       price   latitude   longitude
# 0              3526 HIGH ST      SACRAMENTO  95838     ...       59222  38.631913 -121.434879
# 1               51 OMAHA CT      SACRAMENTO  95823     ...       68212  38.478902 -121.431028
# 2            2796 BRANCH ST      SACRAMENTO  95815     ...       68880  38.618305 -121.443839
# 3          2805 JANETTE WAY      SACRAMENTO  95815     ...       69307  38.616835 -121.439146
# 4           6001 MCMAHON DR      SACRAMENTO  95824     ...       81900  38.519470 -121.435768
# ..                      ...             ...    ...     ...         ...        ...         ...
# 15           7340 HAMDEN PL      SACRAMENTO  95842     ...      110700  38.700051 -121.351278
# 16              6715 6TH ST       RIO LINDA  95673     ...      113263  38.689591 -121.452239
# 17  6236 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621     ...      116250  38.679776 -121.314089
# ...
